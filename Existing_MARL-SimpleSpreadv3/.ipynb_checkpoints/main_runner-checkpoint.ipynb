# %% [markdown]
# ## DQL - New

# %%
from agents.DQLTrain import MultiAgentDQL

trainer = MultiAgentDQL(max_steps=25, checkpoint_interval=10000)
rewards_dql = trainer.train_agents(total_episodes=100000)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/pettingzoo/utils/conversions.py:158: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn(
# Episode 0 ----  Time: 0.0s
# Average Rewards: {'agent_0': -1.06, 'agent_1': -1.06, 'agent_2': -1.06}
#
# Episode 1 ----  Time: 0.02s
# Average Rewards: {'agent_0': -1.08, 'agent_1': -1.02, 'agent_2': -1.08}
#
# Episode 2 ----  Time: 0.01s
# Average Rewards: {'agent_0': -1.29, 'agent_1': -1.29, 'agent_2': -1.23}
#
# Episode 3 ----  Time: 0.01s
# Average Rewards: {'agent_0': -1.44, 'agent_1': -1.4, 'agent_2': -1.44}
#
# Episode 4 ----  Time: 0.01s
# Average Rewards: {'agent_0': -1.12, 'agent_1': -1.12, 'agent_2': -1.12}
#
# Episode 5 ----  Time: 0.01s
# Average Rewards: {'agent_0': -0.95, 'agent_1': -1.01, 'agent_2': -1.01}
#
# Episode 6 ----  Time: 0.01s
# Average Rewards: {'agent_0': -0.85, 'agent_1': -0.85, 'agent_2': -0.85}
#
# Episode 7 ----  Time: 0.01s
# ...

# %%
trainer.plot_reward_curves(rewards_dql)

# %%
trainer.plot_epsilon_decay()

# %% [markdown]
# ## Double DQN New

# %%
from agents.DoubleDQLTrain import MultiAgentDQL

trainer_doubledqn = MultiAgentDQL(max_steps=25, checkpoint_interval=50)
rewards_dql = trainer_doubledqn.train_agents(total_episodes=100)

# %%
trainer_doubledqn.plot_reward_curves(rewards_dql)

# %%
trainer_doubledqn.plot_epsilon_decay()

# %% [markdown]
# ## Dueling Double DQN New

# %%
from agents.DuelingDQLTrain import MultiAgentDQL

trainer_dueling_dql = MultiAgentDQL(max_steps=25, checkpoint_interval=50)
rewards_dueling_dql = trainer_dueling_dql.train_agents(total_episodes=1000)

# %%
trainer_dueling_dql.plot_reward_curves(rewards_dueling_dql)

# %%
trainer_dueling_dql.plot_epsilon_decay()
